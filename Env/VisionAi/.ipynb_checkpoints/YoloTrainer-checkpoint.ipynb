# %%
from ultralytics import YOLO

# %%
# Load a model
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)
model.to('cuda')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[39], line 3
#       1 # Load a model
#       2 model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)
# ----> 3 model.to('cuda')
#
# File ~\anaconda3\envs\HackProject\Lib\site-packages\torch\nn\modules\module.py:1145, in Module.to(self, *args, **kwargs)
#    1141         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                     non_blocking, memory_format=convert_to_format)
#    1143     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1145 return self._apply(convert)
#
# File ~\anaconda3\envs\HackProject\Lib\site-packages\ultralytics\engine\model.py:368, in Model._apply(self, fn)
# ...

# %%
# Use the model
results = model.predict("https://ultralytics.com/images/bus.jpg")  # predict on an image
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 C:\Users\rayan\OneDrive\Bureau\HackProject\CellsAI\Env\VisionAi\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 85.5ms
# Speed: 3.0ms preprocess, 85.5ms inference, 33.0ms postprocess per image at shape (1, 3, 640, 480)

# %%
import os
os.listdir('deadcells.v1i.yolov8/test/images')
# Out:
# ['frame15488_jpg.rf.c14a737ee8d305e0e3adaf53ae19c2d4.jpg',
#  'frame21157_jpg.rf.6864c7608028bd66c3983730cb2a78e1.jpg',
#  'frame37808_jpg.rf.c122559789d43046b81986784b70f332.jpg',
#  'frame4780_jpg.rf.88bc204614befc326caf9a9334318b0e.jpg',
#  'frame7660_jpg.rf.6821679576d6f5e7b51dc468384d1a47.jpg',
#  'frame7840_jpg.rf.6fc019a7ae2f7fe0caf2ed5bd6a7c0e3.jpg']

# %%
#=-------------- Testing of the Ai ---------------#
game_model = YOLO("best.pt")
results = game_model('deadcells.v1i.yolov8/test/images', save=True)
# Out:
# image 1/6 C:\Users\rayan\OneDrive\Bureau\HackProject\CellsAI\Env\VisionAi\deadcells.v1i.yolov8\test\images\frame15488_jpg.rf.c14a737ee8d305e0e3adaf53ae19c2d4.jpg: 640x640 2 agentss, 1 enemy_purple_shield, 649.7ms
# image 2/6 C:\Users\rayan\OneDrive\Bureau\HackProject\CellsAI\Env\VisionAi\deadcells.v1i.yolov8\test\images\frame21157_jpg.rf.6864c7608028bd66c3983730cb2a78e1.jpg: 640x640 1 agents, 1 enemy_green_puncher, 595.3ms
# image 3/6 C:\Users\rayan\OneDrive\Bureau\HackProject\CellsAI\Env\VisionAi\deadcells.v1i.yolov8\test\images\frame37808_jpg.rf.c122559789d43046b81986784b70f332.jpg: 640x640 (no detections), 560.6ms
# image 4/6 C:\Users\rayan\OneDrive\Bureau\HackProject\CellsAI\Env\VisionAi\deadcells.v1i.yolov8\test\images\frame4780_jpg.rf.88bc204614befc326caf9a9334318b0e.jpg: 640x640 1 agents, 560.5ms
# ...

# %%
#--------------- Training starts Here --------------------#
path_to_data = 'deadcells.v1i.yolov8/data.yaml'

model.train(data=path_to_data, epochs=50)  # train the model
# Out:
# Ultralytics YOLOv8.0.206  Python-3.11.5 torch-2.0.1+cpu CPU (AMD Ryzen 7 6800H with Radeon Graphics)
# ...
