# %%
#Import Dependencies
import pyautogui
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
import pygetwindow as gw
from ultralytics import YOLO

# %%
#Get game window
gameWindow = gw.getWindowsWithTitle('Dead Cells')[0]

# %%
#Define game coordinates
gamePosX = 100
gamePosY = 100
gameWidth = 1285
gameHeight = 760

# %%
#move game to coordinates
gameWindow.moveTo(gamePosX,gamePosY)

# %%
pyautogui.screenshot(region=(gamePosX+7, gamePosY, gameWidth, gameHeight))
# Out:
# <PIL.Image.Image image mode=RGB size=1285x760>

# %%
game_model = YOLO("best.pt")

#loop overframe
while True:
    #take a screenshot
    screen = pyautogui.screenshot(region=(gamePosX+7, gamePosY, gameWidth, gameHeight))
    
     # Convert the output to a numpy array
    screen_array = np.array(screen)
    
    # # Crop out the region we want - height, width, channels   
    # cropped_region = screen_array[:750, 620:, :]
    
    # Convert the color channel order
    corrected_colors = cv2.cvtColor(screen_array, cv2.COLOR_RGB2BGR)

    #Make Prediction
    results = game_model.predict(corrected_colors)
    
    # Handle the rendering of the images/video
    cv2.imshow('GameCap', results[0].plot())
    
    # Cv2.waitkey
    if cv2.waitKey(1) & 0xFF==ord('q'):
        break
# Close down the frame
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 854.8ms
# Speed: 4.5ms preprocess, 854.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 746.4ms
# Speed: 3.6ms preprocess, 746.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 691.7ms
# Speed: 4.0ms preprocess, 691.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 707.8ms
# Speed: 4.0ms preprocess, 707.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 703.5ms
# Speed: 4.5ms preprocess, 703.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 714.7ms
# Speed: 4.7ms preprocess, 714.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 761.9ms
# Speed: 4.0ms preprocess, 761.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 714.2ms
# Speed: 3.6ms preprocess, 714.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 705.7ms
# Speed: 5.1ms preprocess, 705.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 639.2ms
# Speed: 4.5ms preprocess, 639.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 649.7ms
# Speed: 4.6ms preprocess, 649.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 702.4ms
# Speed: 4.0ms preprocess, 702.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 659.6ms
# Speed: 4.0ms preprocess, 659.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 715.4ms
# Speed: 3.1ms preprocess, 715.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 735.6ms
# Speed: 8.5ms preprocess, 735.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 743.8ms
# Speed: 4.0ms preprocess, 743.8ms inference, 30.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 888.1ms
# Speed: 4.1ms preprocess, 888.1ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 738.3ms
# Speed: 4.1ms preprocess, 738.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 763.5ms
# Speed: 6.8ms preprocess, 763.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 741.9ms
# Speed: 4.0ms preprocess, 741.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 748.5ms
# Speed: 2.1ms preprocess, 748.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 752.0ms
# Speed: 4.0ms preprocess, 752.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 749.7ms
# Speed: 4.0ms preprocess, 749.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 758.1ms
# Speed: 4.0ms preprocess, 758.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 752.5ms
# Speed: 3.5ms preprocess, 752.5ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 774.3ms
# Speed: 1.6ms preprocess, 774.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 754.6ms
# Speed: 6.0ms preprocess, 754.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 750.1ms
# Speed: 4.0ms preprocess, 750.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 774.2ms
# Speed: 5.6ms preprocess, 774.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 753.5ms
# Speed: 4.0ms preprocess, 753.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 738.5ms
# Speed: 3.6ms preprocess, 738.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 719.2ms
# Speed: 4.5ms preprocess, 719.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 753.8ms
# Speed: 6.1ms preprocess, 753.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 755.9ms
# Speed: 4.0ms preprocess, 755.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 736.8ms
# Speed: 3.5ms preprocess, 736.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 764.8ms
# Speed: 3.9ms preprocess, 764.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 747.8ms
# Speed: 4.2ms preprocess, 747.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 916.5ms
# Speed: 7.5ms preprocess, 916.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents,
1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 764.0ms
# Speed: 6.0ms preprocess, 764.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 775.5ms
# Speed: 8.5ms preprocess, 775.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 773.5ms
# Speed: 8.5ms preprocess, 773.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 835.7ms
# Speed: 8.5ms preprocess, 835.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 779.7ms
# Speed: 4.5ms preprocess, 779.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 792.4ms
# Speed: 6.1ms preprocess, 792.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 803.7ms
# Speed: 8.0ms preprocess, 803.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 806.3ms
# Speed: 3.5ms preprocess, 806.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 767.9ms
# Speed: 3.5ms preprocess, 767.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 766.1ms
# Speed: 3.5ms preprocess, 766.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 765.4ms
# Speed: 4.5ms preprocess, 765.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 758.8ms
# Speed: 3.5ms preprocess, 758.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 768.3ms
# Speed: 3.5ms preprocess, 768.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 790.2ms
# Speed: 4.1ms preprocess, 790.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 808.1ms
# Speed: 4.0ms preprocess, 808.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 733.8ms
# Speed: 4.0ms preprocess, 733.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 732.0ms
# Speed: 3.5ms preprocess, 732.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 752.3ms
# Speed: 3.9ms preprocess, 752.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 749.7ms
# Speed: 8.1ms preprocess, 749.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 771.7ms
# Speed: 11.5ms preprocess, 771.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 739.6ms
# Speed: 4.1ms preprocess, 739.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 758.4ms
# Speed: 4.1ms preprocess, 758.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 754.1ms
# Speed: 2.0ms preprocess, 754.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 745.5ms
# Speed: 4.0ms preprocess, 745.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 788.0ms
# Speed: 3.6ms preprocess, 788.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 794.4ms
# Speed: 4.0ms preprocess, 794.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 796.4ms
# Speed: 4.0ms preprocess, 796.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 731.8ms
# Speed: 4.0ms preprocess, 731.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 781.8ms
# Speed: 3.5ms preprocess, 781.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 737.8ms
# Speed: 8.0ms preprocess, 737.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 733.7ms
# Speed: 6.1ms preprocess, 733.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 793.6ms
# Speed: 4.0ms preprocess, 793.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 747.9ms
# Speed: 4.0ms preprocess, 747.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 759.8ms
# Speed: 6.6ms preprocess, 759.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 agentss, 772.0ms
# Speed: 3.5ms preprocess, 772.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 739.8ms
# Speed: 2.0ms preprocess, 739.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 1 enemy_green_puncher, 735.4ms
# Speed: 4.5ms preprocess, 735.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 2 enemy_green_punchers, 788.5ms
# Speed: 4.1ms preprocess, 788.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 2 enemy_green_punchers, 776.3ms
# Speed: 7.6ms preprocess, 776.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 738.8ms
# Speed: 4.1ms preprocess, 738.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 agentss, 755.9ms
# Speed: 4.0ms preprocess, 755.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 887.6ms
# Speed: 2.5ms preprocess, 887.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 1 enemy_green_puncher, 742.2ms
# Speed: 3.1ms preprocess, 742.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 2 enemy_green_punchers, 955.8ms
# Speed: 8.0ms preprocess, 955.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 2 enemy_green_punchers, 743.4ms
# Speed: 4.5ms preprocess, 743.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 agentss, 2 enemy_green_punchers, 1 enemy_purple_big, 787.3ms
# Speed: 4.5ms preprocess, 787.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 2 enemy_green_punchers, 768.8ms
# Speed: 6.0ms preprocess, 768.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 1 enemy_green_puncher, 760.4ms
# Speed: 3.5ms preprocess, 760.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 1 enemy_green_puncher, 803.8ms
# Speed: 3.5ms preprocess, 803.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 1 enemy_green_puncher, 804.1ms
# Speed: 3.6ms preprocess, 804.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 enemy_green_punchers, 795.4ms
# Speed: 4.5ms preprocess, 795.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 772.2ms
# Speed: 4.0ms preprocess, 772.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 enemy_green_puncher, 762.2ms
# Speed: 8.1ms preprocess, 762.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 agents, 1 enemy_green_puncher, 749.4ms
# Speed: 4.5ms preprocess, 749.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 enemy_green_puncher, 781.7ms
# Speed: 2.0ms preprocess, 781.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 enemy_green_puncher, 756.4ms
# Speed: 3.6ms preprocess, 756.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections),