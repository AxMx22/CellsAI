# %%
import pyautogui
import time
import keyboard
import os
import random

# %%
def goRight():
    pyautogui.keyDown('right')
    time.sleep(2)
    pyautogui.keyUp('right')

def goLeft():
    pyautogui.keyDown('left')
    time.sleep(2)
    pyautogui.keyUp('left')

def jump():
    pyautogui.keyDown('space')
    time.sleep(0.5)
    pyautogui.keyUp('space')

def crouch():
    pyautogui.keyDown('down')
    time.sleep(0.5)
    pyautogui.keyUp('down')


def doubleJump():
    jump()
    jump()

def quickRight():
    goRight()
    time.sleep(0.1)
    goRight()

def quickLeft():
    goLeft()
    time.sleep(0.1)
    goLeft()

def dashRight():
    quickRight()
    quickRight()
    
def dashLeft():
    quickLeft()
    quickLeft()

    
def climb():
    pyautogui.keyDown('up')
    time.sleep(0.5)
    pyautogui.keyUp('up')

def roll():
    pyautogui.keyDown('ctrl')
    time.sleep(0.5)
    pyautogui.keyUp('ctrl')

def weapon1():
    pyautogui.keyDown('1')
    time.sleep(0.5)
    #left-click
    pyautogui.keyUp('1')

def weapon2():
    pyautogui.keyDown('2')
    #right-click
    time.sleep(0.5)

pyautogui.keyUp('2')

def health():
    pyautogui.keyDown('h')
    time.sleep(0.5)
    pyautogui.keyUp('h')

def collect():
    pyautogui.keyDown('r')
    time.sleep(0.5)
    pyautogui.keyUp('r')

def jump():
    pyautogui.keyDown('space')
    time.sleep(0.5)
    pyautogui.keyUp('space')

def Quickjump():
    pyautogui.keyDown('space')
    time.sleep(0.05)
    pyautogui.keyUp('space')

def doubleJump():
    Quickjump()
    Quickjump()
    
def hardStomp():
    pyautogui.keyDown('down')
    time.sleep(0.05)
    doubleJump()
    pyautogui.keyUp('down')

def jumpDown():
    pyautogui.keyDown('down')
    time.sleep(0.05)
    jump()
    pyautogui.keyUp('down')

# %%
os.startfile(r"C:\\Users\\rayan\\OneDrive\\Bureau\\HackProject\\CellsAI\\Game\\deadcells.exe") 

# Wait for a few seconds to ensure the game has loaded
time.sleep(15)

#start Game
Quickjump()
Quickjump()

# time.sleep(5)
# #run vision AI
# %run ../Demo_env/AiVision.ipynb

run = True;

def Stop_game():
    run = False;
    print('i Stopped it')
keyboard.add_hotkey('esc', Stop_game())

# %%
def Action1():
    print('Action1')

def Action2():
    print('Action2')

def Action3():
    print('Action3')
    
actionList = [Action1,Action2,Action3]

while True:
    # Pick a random action from the actionList
    random_action = random.choice(actionList)
    
    # Call the randomly chosen action
    random_action()

    if keyboard.is_pressed('esc'):
        print('esc was pressed')
        break
    # keyboard.wait('esc')

# %%
while True:
    print('I am running 1')
    print('I am running 2')
    print('I am running 3')
    print('I am running 4')
    break
# Out:
# I am running 1
# I am running 2
# I am running 3
# I am running 4

# %%
while not keyboard.is_pressed('backspace'):
    goRight()
    goRight()
    doubleJump()
    doubleJump()
    doubleJump()
    doubleJump()
    roll()
    roll()
    crouch()
    crouch()
    jump()
    jump()
    collect()
    collect()
    weapon1()
    weapon1()
    doubleJump()
    doubleJump()
    roll()
    roll()
    weapon1()
    weapon1()
    weapon1()
    weapon1()
    roll()
    roll()
    roll()
    jumpDown()
    jumpDown()
    collect()
    collect()
    dashRight()
    dashRight()
    goRight()
    goRight()
    dashRight()
    roll()
    roll()
    goLeft()
    weapon1()
    weapon1()
    weapon1()
    doubleJump()
    doubleJump()
    weapon1()
    weapon1()
    weapon1()
    roll()
    roll()
    jumpDown()
    jumpDown()
    goRight()
    goRight()    
    weapon1()
    weapon1()
    weapon1()
    roll()
    roll()
    doubleJump()
    doubleJump()
    goLeft()
    weapon1()
    weapon1()
    weapon1()
    doubleJump()
    doubleJump()
    goRight()
    roll()
    roll()
    roll()
    doubleJump()
    climb()
    roll()
    hardStomp()    
    hardStomp()
    doubleJump()     
    weapon1()
    weapon2()
    health()
    collect()
    climb()
    climb()
    climb()
    doubleJump()
    doubleJump()
    climb()
    climb()
    climb()
    climb()
    climb()
    goRight()
    jumpDown()
    jumpDown()
    jump()
    jump()
    roll()
    roll()
    roll()
    crouch()
    jump()
    goRight()
    pass

# %%
# Out:
# You pressed  f
# You pressed  f
# You pressed  w
# You pressed  w
# You pressed  esc
# You pressed  esc
# You pressed  backspace
# You pressed  backspace
# You pressed  space
# You pressed  space
# You pressed  space
# You pressed  space
# You pressed  f
# You pressed  f
# You pressed  g
# You pressed  g
# You pressed  t
# You pressed  t
# You pressed  e
# You pressed  e
# You pressed  y
# You pressed  y
# You pressed  a
# You pressed 'a'.
